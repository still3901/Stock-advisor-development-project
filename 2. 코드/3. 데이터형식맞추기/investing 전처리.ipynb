# %%
### 필요한 라이브러리 설치
# !pip install finance-datareader
# !pip install plotly

# %%
import pandas as pd
path = r'C:\Users\still\crawler\인베스팅닷컴 df\combined_df.csv'
df= pd.read_csv(path)

# %%
# df.rename(columns={'Time': 'Date'}, inplace=True)
new_column_names = {'comments': 'Text', 'date':'Date'}
df['type'] = df['type'].replace({'NVDI': 'NVDA'})
df.rename(columns=new_column_names, inplace=True)

# %%
df['src']='investing'

# 사용자 정의 함수 정의
def convert_date(date):
    if len(date) == 10:  # 시간 정보가 없는 경우
        return date
    else:
        return date[:10]  # 시간 정보가 있는 경우에는 날짜 부분만 추출하여 반환

# 'Date' 열에 함수 적용하여 날짜를 yyyy-mm-dd 형식의 문자열로 변환
df['Date'] = df['Date'].apply(convert_date)

# 결과 출력
print(df)
df
# Out:
#                                                   head        Date  \
# 0    Axcelis Technologies director sells over $137k...  2024-05-21
# 1    Tech sector: Which stocks will dominate the ma...  2024-04-26
# 2    Axcelis Tech receives Investment Bank Analyst ...  2024-05-03
# 3    Axcelis Tech receives Investment Bank Analyst ...  2024-05-03
# 4    Citi maintains buy rating on Analog Devices stock  2024-05-21
# ..                                                 ...         ...
# 792      Wolfspeed stock slips as guidance disappoints  2024-05-02
# 793  Wolfspeed stock PT lowered by Citi on margin m...  2024-05-02
# 794  Cree Inc. receives Investment Bank Analyst Rat...  2024-05-02
# 795  Cree Inc. receives Investment Bank Analyst Rat...  2024-05-02
# 796  US picks 31 regional hubs to spur tech innovation  2023-10-23
#
#                                                   Text  type        src
# 0                                     pure advertising  ACLS  investing
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
# 'type' 컬럼의 각 값 앞에 '$'를 붙이는 작업
df['type'] = df['type'].apply(lambda x: f'${x}')
df.type.unique()
# Out:
# array(['$ACLS', '$ADI', '$AMAT', '$AMD', '$ASML', '$AVGO', '$ENTG',
#        '$INTC', '$KLAC', '$LRCX', '$LSCC', '$MCHP', '$MKSI', '$MPWR',
#        '$MRVL', '$MU', '$NVDA', '$NXPI', '$ON', '$QCOM', '$QRVO', '$RMBS',
#        '$STM', '$SWKS', '$TER', '$TSMC', '$TXN', '$UMC', '$WOLF', '$ASX'],
#       dtype=object)

# %%
types = ['$ACLS', '$ADI', '$AMAT', '$AMD', '$ASML', '$AVGO', '$ENTG',
       '$INTC', '$KLAC', '$LRCX', '$LSCC', '$MCHP', '$MKSI', '$MPWR',
       '$MRVL', '$MU', '$NVDA', '$NXPI', '$ON', '$QCOM', '$QRVO', '$RMBS',
       '$STM', '$SWKS', '$TER', '$TSMC', '$TXN', '$UMC', '$WOLF', '$ASX']

# 딕셔너리에 필터링된 DataFrame 저장
filtered_dfs = {t: df[df['type'] == t] for t in types}

# 딕셔너리에서 개별 DataFrame 접근 방법
df_ADI = filtered_dfs['$ADI']
df_AMAT = filtered_dfs['$AMAT']
df_AMD = filtered_dfs['$AMD']
df_ASML = filtered_dfs['$ASML']
df_AVGO = filtered_dfs['$AVGO']
df_INTC = filtered_dfs['$INTC']
df_LRCX = filtered_dfs['$LRCX']
df_MCHP = filtered_dfs['$MCHP']
df_MPWR = filtered_dfs['$MPWR']
df_MRVL = filtered_dfs['$MRVL']
df_MU = filtered_dfs['$MU']
df_NVDA = filtered_dfs['$NVDA']
df_NXPI = filtered_dfs['$NXPI']
df_QCOM = filtered_dfs['$QCOM']
df_TER = filtered_dfs['$TER']
df_TXN = filtered_dfs['$TXN']

df_ACLS = filtered_dfs['$ACLS']
df_ASX = filtered_dfs['$ASX']
df_ENTG = filtered_dfs['$ENTG']
df_KLAC = filtered_dfs['$KLAC']
df_LSCC = filtered_dfs['$LSCC']
df_MKSI = filtered_dfs['$MKSI']
df_ON = filtered_dfs['$ON']
df_QRVO = filtered_dfs['$QRVO']
df_RMBS = filtered_dfs['$RMBS']
df_STM = filtered_dfs['$STM']
df_SWKS = filtered_dfs['$SWKS']
df_TSMC = filtered_dfs['$TSMC']
df_UMC = filtered_dfs['$UMC']
df_WOLF = filtered_dfs['$WOLF']

# %%
import FinanceDataReader as fdr
import pandas as pd

# ADI 데이터 불러오기
# df_adi = fdr.DataReader('ADI', start='2023')
df_acls = fdr.DataReader('ACLS', start='2023')
df_acls.reset_index(inplace=True)
df_adi = fdr.DataReader('ADI', start='2023')
df_adi.reset_index(inplace=True)
df_amat = fdr.DataReader('AMAT', start='2023')
df_amat.reset_index(inplace=True)
df_amd = fdr.DataReader('AMD', start='2023')
df_amd.reset_index(inplace=True)
df_asml = fdr.DataReader('ASML', start='2023')
df_asml.reset_index(inplace=True)
df_avgo = fdr.DataReader('AVGO', start='2023')
df_avgo.reset_index(inplace=True)
df_entg = fdr.DataReader('ENTG', start='2023')
df_entg.reset_index(inplace=True)
df_intc = fdr.DataReader('INTC', start='2023')
df_intc.reset_index(inplace=True)
df_klac = fdr.DataReader('KLAC', start='2023')
df_klac.reset_index(inplace=True)
df_lrcx = fdr.DataReader('LRCX', start='2023')
df_lrcx.reset_index(inplace=True)
df_lscc = fdr.DataReader('LSCC', start='2023')
df_lscc.reset_index(inplace=True)
df_mchp = fdr.DataReader('MCHP', start='2023')
df_mchp.reset_index(inplace=True)
df_mksi = fdr.DataReader('MKSI', start='2023')
df_mksi.reset_index(inplace=True)
df_mpwr = fdr.DataReader('MPWR', start='2023')
df_mpwr.reset_index(inplace=True)
df_mrvl = fdr.DataReader('MRVL', start='2023')
df_mrvl.reset_index(inplace=True)
df_mu = fdr.DataReader('MU', start='2023')
df_mu.reset_index(inplace=True)
df_nvda = fdr.DataReader('NVDA', start='2023')
df_nvda.reset_index(inplace=True)
df_nxpi = fdr.DataReader('NXPI', start='2023')
df_nxpi.reset_index(inplace=True)
df_on = fdr.DataReader('ON', start='2023')
df_on.reset_index(inplace=True)
df_qcom = fdr.DataReader('QCOM', start='2023')
df_qcom.reset_index(inplace=True)
df_qrvo = fdr.DataReader('QRVO', start='2023')
df_qrvo.reset_index(inplace=True)
df_rmbs = fdr.DataReader('RMBS', start='2023')
df_rmbs.reset_index(inplace=True)
df_stm = fdr.DataReader('STM', start='2023')
df_stm.reset_index(inplace=True)
df_swks = fdr.DataReader('SWKS', start='2023')
df_swks.reset_index(inplace=True)
df_ter = fdr.DataReader('TER', start='2023')
df_ter.reset_index(inplace=True)
df_tsmc = fdr.DataReader('TSMC', start='2023')
df_tsmc.reset_index(inplace=True)
df_txn = fdr.DataReader('TXN', start='2023')
df_txn.reset_index(inplace=True)
df_umc = fdr.DataReader('UMC', start='2023')
df_umc.reset_index(inplace=True)
df_wolf = fdr.DataReader('WOLF', start='2023')
df_wolf.reset_index(inplace=True)
df_asx = fdr.DataReader('ASX', start='2023')
df_asx.reset_index(inplace=True)


# 'Date' 인덱스를 컬럼으로 변환
# df_adi.reset_index(inplace=True)

# 예제 DataFrame 생성 (병합할 다른 DataFrame)
# 이 DataFrame은 실제 데이터로 대체할 수 있습니다.
# Out:
# HTTP Error 404: Not Found  - symbol "TSMC" not found or invalid periods

# %%
tsmc_rows = df[df['type'] == 'TSMC']
tsmc_rows
# Out:
# Empty DataFrame
# Columns: [head, Date, Text, type, src]
# Index: []

# %%
# 주식 종목 리스트
types = ['$ACLS', '$ADI', '$AMAT', '$AMD', '$ASML', '$AVGO', '$ENTG',
         '$INTC', '$KLAC', '$LRCX', '$LSCC', '$MCHP', '$MKSI', '$MPWR',
         '$MRVL', '$MU', '$NVDA', '$NXPI', '$ON', '$QCOM', '$QRVO', '$RMBS',
         '$STM', '$SWKS', '$TER', '$TSMC', '$TXN', '$UMC', '$WOLF', '$ASX']

# %% [markdown]
# # 새 섹션

# %%
# 원본 데이터를 저장

df_acls_original = df_acls.copy()
df_adi_original = df_adi.copy()
df_amat_original = df_amat.copy()
df_amd_original = df_amd.copy()
df_asml_original = df_asml.copy()
df_avgo_original = df_avgo.copy()
df_entg_original = df_entg.copy()
df_intc_original = df_intc.copy()
df_klac_original = df_klac.copy()
df_lrcx_original = df_lrcx.copy()
df_lscc_original = df_lscc.copy()
df_mchp_original = df_mchp.copy()
df_mksi_original = df_mksi.copy()
df_mpwr_original = df_mpwr.copy()
df_mrvl_original = df_mrvl.copy()
df_mu_original = df_mu.copy()
df_nvda_original = df_nvda.copy()
df_nxpi_original = df_nxpi.copy()
df_on_original = df_on.copy()
df_qcom_original = df_qcom.copy()
df_qrvo_original = df_qrvo.copy()
df_rmbs_original = df_rmbs.copy()
df_stm_original = df_stm.copy()
df_swks_original = df_swks.copy()
df_ter_original = df_ter.copy()
df_tsmc_original = df_tsmc.copy()
df_txn_original = df_txn.copy()
df_umc_original = df_umc.copy()
df_wolf_original = df_wolf.copy()
df_asx_original = df_asx.copy()

# %% [markdown]
# ### ADI

# %%
df_ADI['Date'] = pd.to_datetime(df_ADI['Date'])
# 'Date' 컬럼을 기준으로 병합
df_adi = pd.merge(df_ADI, df_adi_original, on='Date', how='inner')
df_adi
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\980619468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ADI['Date'] = pd.to_datetime(df_ADI['Date'])
#                                                  head       Date  \
# 0   Citi maintains buy rating on Analog Devices stock 2024-05-21
# 1   Citi maintains buy rating on Analog Devices stock 2024-05-21
# 2   Citi maintains buy rating on Analog Devices stock 2024-05-21
# 3   Citi maintains buy rating on Analog Devices stock 2024-05-21
# 4   Stifel raises Analog Devices shares target cit... 2024-05-21
# 5           March chip sales above seasonality - Citi 2024-05-06
# 6   Congressman Jonathan Jackson makes significant... 2024-04-26
# ...

# %% [markdown]
# ### AMAT

# %%
df_AMAT['Date'] = pd.to_datetime(df_AMAT['Date'])
# 'Date' 컬럼을 기준으로 병합
df_amat = pd.merge(df_AMAT, df_amat_original, on='Date', how='inner')
df_amat
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\2137679898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AMAT['Date'] = pd.to_datetime(df_AMAT['Date'])
#                                                 head       Date  \
# 0  Citi raises Applied Materials shares target on... 2024-05-21
# 1  Citi lifts Applied Materials shares target on ... 2024-05-17
# 2  Citi lifts Applied Materials shares target on ... 2024-05-17
# 3  Citi lifts Applied Materials shares target on ... 2024-05-17
# 4  KeyBanc maintains Sector Weight on Applied Mat... 2024-05-17
# 5  Stifel raises Applied Materials shares target ... 2024-05-17
# 6  Applied Materials to Participate in Upcoming I... 2024-05-17
# ...

# %% [markdown]
# AMD

# %%
df_AMD['Date'] = pd.to_datetime(df_AMD['Date'])
# 'Date' 컬럼을 기준으로 병합
df_amd = pd.merge(df_AMD, df_amd_original, on='Date', how='inner')
df_amd
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1476228683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AMD['Date'] = pd.to_datetime(df_AMD['Date'])
#                                                  head       Date  \
# 0   Cathie Wood's ARK ETF adjusts portfolio with m... 2024-05-21
# 1   Cathie Wood's ARK ETF adjusts portfolio with m... 2024-05-21
# 2   Cathie Wood's ARK ETF adjusts portfolio with m... 2024-05-21
# 3                        US stock futures tread water 2024-05-21
# 4                        US stock futures tread water 2024-05-21
# ..                                                ...        ...
# 91  Dow futures slip; Caterpillar earnings, JOLTs ... 2023-08-01
# ...

# %% [markdown]
# ASML

# %%
df_ASML['Date'] = pd.to_datetime(df_ASML['Date'])
# 'Date' 컬럼을 기준으로 병합
df_asml = pd.merge(df_ASML, df_asml_original, on='Date', how='inner')
df_asml
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3681908995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ASML['Date'] = pd.to_datetime(df_ASML['Date'])
#                                                 head       Date  \
# 0  Congressman Jonathan Jackson makes significant... 2024-04-26
# 1  Analysis-New ASML boss Fouquet must navigate U... 2024-04-25
# 2  TSMC says 'A16' chipmaking tech to arrive in 2... 2024-04-24
# 3  ASML approves Christophe Fouquet as CEO at ann... 2024-04-24
# 4  ASML shares hold Buy rating amid cautious outlook 2024-04-22
# 5  Asml Holding receives Investment Bank Analyst ... 2024-05-21
# 6  Asml Holding receives Investment Bank Analyst ... 2024-05-21
# ...

# %% [markdown]
# AVGO

# %%
df_AVGO['Date'] = pd.to_datetime(df_AVGO['Date'])
# 'Date' 컬럼을 기준으로 병합
df_avgo = pd.merge(df_AVGO, df_avgo_original, on='Date', how='inner')
df_avgo
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1247890029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AVGO['Date'] = pd.to_datetime(df_AVGO['Date'])
#                                                  head       Date  \
# 0   Amazon, Coca Cola and these 2 stocks are added... 2024-05-16
# 1   Amazon, Coca Cola and these 2 stocks are added... 2024-05-16
# 2   Amazon, Coca Cola and these 2 stocks are added... 2024-05-16
# 3   Amazon, Coca Cola and these 2 stocks are added... 2024-05-16
# 4   Amazon, Coca Cola and these 2 stocks are added... 2024-05-16
# ..                                                ...        ...
# 62  Here's why investors seem to be hesitant to ow... 2024-05-17
# ...

# %% [markdown]
# INTEL

# %%
df_INTC['Date'] = pd.to_datetime(df_INTC['Date'])
# 'Date' 컬럼을 기준으로 병합
df_intc = pd.merge(df_INTC, df_intc_original, on='Date', how='inner')
df_intc
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1214493716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_INTC['Date'] = pd.to_datetime(df_INTC['Date'])
#                                                  head       Date  \
# 0   European labs led by imec to receive $2.7 bill... 2024-05-21
# 1   ROSEN, LEADING INVESTOR COUNSEL, Encourages In... 2024-05-21
# 2    Microsoft debuts 'Copilot+' PCs with AI features 2024-05-21
# 3    Microsoft debuts 'Copilot+' PCs with AI features 2024-05-21
# 4    Microsoft debuts 'Copilot+' PCs with AI features 2024-05-21
# 5                        US stock futures tread water 2024-05-21
# 6                        US stock futures tread water 2024-05-21
# ...

# %% [markdown]
# LRCX

# %%
df_LRCX['Date'] = pd.to_datetime(df_LRCX['Date'])
# 'Date' 컬럼을 기준으로 병합
df_lrcx = pd.merge(df_LRCX, df_lrcx_original, on='Date', how='inner')
df_lrcx
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3082287829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_LRCX['Date'] = pd.to_datetime(df_LRCX['Date'])
#                                                  head       Date  \
# 0   FormFactor (FORM) To Report Earnings Tomorrow:... 2024-04-30
# 1   FormFactor (FORM) To Report Earnings Tomorrow:... 2024-04-30
# 2   IPG Photonics Earnings: What To Look For From ... 2024-04-29
# 3   IPG Photonics Earnings: What To Look For From ... 2024-04-29
# 4   Kulicke and Soffa (KLIC) Reports Q1: Everythin... 2024-04-30
# 5   Kulicke and Soffa (KLIC) Reports Q1: Everythin... 2024-04-30
# 6   Lam Research Corp receives Investment Bank Ana... 2024-05-13
# ...

# %% [markdown]
# MCHP

# %%
df_MCHP['Date'] = pd.to_datetime(df_MCHP['Date'])
# 'Date' 컬럼을 기준으로 병합
df_mchp = pd.merge(df_MCHP, df_mchp_original, on='Date', how='inner')
df_mchp
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3743038598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_MCHP['Date'] = pd.to_datetime(df_MCHP['Date'])
#                                                  head       Date  \
# 0   Earnings call: Microchip Technology reports Q4... 2024-05-07
# 1   Earnings call: Microchip Technology reports Q4... 2024-05-07
# 2   Earnings call: Microchip Technology reports Q4... 2024-05-07
# 3   Earnings call: Microchip Technology reports Q4... 2024-05-07
# 4   Earnings call: Microchip Technology reports Q4... 2024-05-07
# 5   Microchip Expands its Radiation-Tolerant Micro... 2024-05-16
# 6   Microchip Expands its Radiation-Tolerant Micro... 2024-05-16
# ...

# %% [markdown]
# MPWR

# %%
df_MPWR['Date'] = pd.to_datetime(df_MPWR['Date'])
# 'Date' 컬럼을 기준으로 병합
df_mpwr = pd.merge(df_MPWR, df_mpwr_original, on='Date', how='inner')
df_mpwr
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3523655583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_MPWR['Date'] = pd.to_datetime(df_MPWR['Date'])
#                                                 head       Date  \
# 0  Monolithic Power Systems EVP sells shares wort... 2024-05-09
# 1  Monolithic Power receives Investment Bank Anal... 2024-05-02
# 2  Why Is Monolithic Power Systems (MPWR) Stock S... 2024-05-02
# 3  Why Is Monolithic Power Systems (MPWR) Stock S... 2024-05-02
# 4  Why Is Monolithic Power Systems (MPWR) Stock S... 2024-05-02
# 5  Why Is Monolithic Power Systems (MPWR) Stock S... 2024-05-02
# 6  Why Is Monolithic Power Systems (MPWR) Stock S... 2024-05-02
#
# ...

# %% [markdown]
# MRVL

# %%
df_MRVL['Date'] = pd.to_datetime(df_MRVL['Date'])
# 'Date' 컬럼을 기준으로 병합
df_mrvl = pd.merge(df_MRVL, df_mrvl_original, on='Date', how='inner')
df_mrvl
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\2180273400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_MRVL['Date'] = pd.to_datetime(df_MRVL['Date'])
#                                                  head       Date  \
# 0   Here's why investors seem to be hesitant to ow... 2024-05-17
# 1   Here's why investors seem to be hesitant to ow... 2024-05-17
# 2   Here's why investors seem to be hesitant to ow... 2024-05-17
# 3   Here's why investors seem to be hesitant to ow... 2024-05-17
# 4   Marvell CEO Matthew Murphy sells $2.08 million... 2024-05-16
# ..                                                ...        ...
# 82  Marvell Technology Appoints Rick Wallace and D... 2024-04-29
# ...

# %% [markdown]
# MU

# %%
df_MU['Date'] = pd.to_datetime(df_MU['Date'])
# 'Date' 컬럼을 기준으로 병합
df_mu = pd.merge(df_MU, df_mu_original, on='Date', how='inner')
df_mu
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\2409467479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_MU['Date'] = pd.to_datetime(df_MU['Date'])
#                                                  head       Date  \
# 0   Micron CEO Sanjay Mehrotra sells shares worth ... 2024-05-16
# 1   Micron CEO Sanjay Mehrotra sells shares worth ... 2024-05-16
# 2   Micron CEO Sanjay Mehrotra sells shares worth ... 2024-05-16
# 3   Micron Tech receives Investment Bank Analyst R... 2024-05-21
# 4   Micron Tech receives Investment Bank Analyst R... 2024-05-21
# 5   Micron Tech receives Investment Bank Analyst R... 2024-05-21
# 6   Micron Tech receives Investment Bank Analyst R... 2024-05-21
# ...

# %% [markdown]
# NVDA

# %%
df_NVDA['Date'] = pd.to_datetime(df_NVDA['Date'])
# 'Date' 컬럼을 기준으로 병합
df_nvda = pd.merge(df_NVDA, df_nvda_original, on='Date', how='inner')
df_nvda
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3254208310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NVDA['Date'] = pd.to_datetime(df_NVDA['Date'])
#                                                   head       Date  \
# 0    Nasdaq slips from record high on Fed policy ca... 2024-05-22
# 1    Nasdaq slips from record high on Fed policy ca... 2024-05-22
# 2    Nasdaq slips from record high on Fed policy ca... 2024-05-22
# 3    Amazon's cloud unit pauses orders of Nvidia's ... 2024-05-22
# 4    Amazon's cloud unit pauses orders of Nvidia's ... 2024-05-22
# ..                                                 ...        ...
# 104  Stock Market Today: S&P 500, Nasdaq in record ... 2024-05-22
# ...

# %% [markdown]
# NXPI

# %%
df_NXPI['Date'] = pd.to_datetime(df_NXPI['Date'])
# 'Date' 컬럼을 기준으로 병합
df_nxpi = pd.merge(df_NXPI, df_nxpi_original, on='Date', how='inner')
df_nxpi
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\2839849491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NXPI['Date'] = pd.to_datetime(df_NXPI['Date'])
#                                                  head       Date  \
# 0   NXP Semiconductors stock target increased on M... 2024-05-01
# 1   NXP Semiconductors stock target increased on M... 2024-05-01
# 2   NXP Semiconductors stock target increased on M... 2024-05-01
# 3   NXP Semiconductors stock target increased on M... 2024-05-01
# 4   NXP Semiconductors stock target increased on M... 2024-05-01
# 5   Argus bullish on NXP Semiconductors shares aft... 2024-05-01
# 6   Argus bullish on NXP Semiconductors shares aft... 2024-05-01
# ...

# %% [markdown]
# QCOM

# %%
df_QCOM['Date'] = pd.to_datetime(df_QCOM['Date'])
# 'Date' 컬럼을 기준으로 병합
df_qcom = pd.merge(df_QCOM, df_qcom_original, on='Date', how='inner')
df_qcom
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\698557570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_QCOM['Date'] = pd.to_datetime(df_QCOM['Date'])
#                                                  head       Date  \
# 0    Microsoft debuts 'Copilot+' PCs with AI features 2024-05-21
# 1   Dell deepens AI push with new PCs, Nvidia-powe... 2024-05-21
# 2   Dell deepens AI push with new PCs, Nvidia-powe... 2024-05-21
# 3   Dell deepens AI push with new PCs, Nvidia-powe... 2024-05-21
# 4   Departing Boeing CEO's board status faces Frid... 2024-05-17
# 5   Qualcomm CEO Cristiano Amon sells $1.54 millio... 2024-05-16
# 6   Qualcomm director Sylvia Acevedo sells shares ... 2024-05-13
# ...

# %% [markdown]
# TER

# %%
df_ter
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-01-03   88.849998   89.160004   85.550003   85.930000   85.381950
# 1   2023-01-04   87.239998   87.879997   85.750000   87.419998   86.862442
# 2   2023-01-05   86.839996   88.419998   85.949997   87.120003   86.564369
# 3   2023-01-06   88.279999   91.800003   87.730003   91.239998   90.658081
# 4   2023-01-09   92.940002   95.830002   92.370003   93.209999   92.615524
# ..         ...         ...         ...         ...         ...         ...
# 345 2024-05-17  132.589996  133.460007  130.899994  131.910004  131.796539
# 346 2024-05-20  135.000000  140.220001  134.690002  139.509995  139.389999
# 347 2024-05-21  137.750000  140.639999  137.389999  140.270004  140.270004
# 348 2024-05-22  140.729996  143.009995  139.690002  142.860001  142.860001
# 349 2024-05-23  145.220001  145.639999  138.929993  140.250000  140.250000
#
#       Volume
# 0    1033200
# 1    2025400
# 2     998700
# ...

# %%
df_TER
# Out:
#                                                   head       Date  \
# 737  Teradyne CFO Sanjay Mehta sells $450k in compa... 2024-05-07
# 738  Teradyne director Johnson Mercedes sells $75,7... 2024-05-08
# 739  Teradyne director Johnson Mercedes sells $75,7... 2024-05-08
# 740  Teradyne director Johnson Mercedes sells $75,7... 2024-05-08
#
#                                                   Text  type        src
# 737  I want to share my experience and tell you how...  $TER  investing
# 738      Welcome Open Market and Free Trade, said USA.  $TER  investing
# 739  USA screwed..i don't think so...the Chinese ma...  $TER  investing
# 740  CEO of companies operating in China - must hav...  $TER  investing

# %%
df_TER['Date'] = pd.to_datetime(df_TER['Date'])
# 'Date' 컬럼을 기준으로 병합
df_ter = pd.merge(df_TER, df_ter_original, on='Date', how='inner')
df_ter
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1124850884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TER['Date'] = pd.to_datetime(df_TER['Date'])
#                                                 head       Date  \
# 0  Teradyne CFO Sanjay Mehta sells $450k in compa... 2024-05-07
# 1  Teradyne director Johnson Mercedes sells $75,7... 2024-05-08
# 2  Teradyne director Johnson Mercedes sells $75,7... 2024-05-08
# 3  Teradyne director Johnson Mercedes sells $75,7... 2024-05-08
#
#                                                 Text  type        src  \
# 0  I want to share my experience and tell you how...  $TER  investing
# 1      Welcome Open Market and Free Trade, said USA.  $TER  investing
# ...

# %% [markdown]
# TXN

# %%
df_TXN['Date'] = pd.to_datetime(df_TXN['Date'])
# 'Date' 컬럼을 기준으로 병합
df_txn = pd.merge(df_TXN, df_txn_original, on='Date', how='inner')
df_txn
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3930934569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TXN['Date'] = pd.to_datetime(df_TXN['Date'])
#                                                  head       Date  \
# 0   Texas Instruments started at underweight by We... 2024-05-16
# 1   Texas Instruments started at underweight by We... 2024-05-16
# 2   Texas Instruments started at underweight by We... 2024-05-16
# 3   Texas Instruments started at underweight by We... 2024-05-16
# 4   Texas Instruments started at underweight by We... 2024-05-16
# 5   Wells Fargo starts Texas Instruments stock cit... 2024-05-16
# 6   Wells Fargo starts Texas Instruments stock cit... 2024-05-16
# ...

# %% [markdown]
# acls

# %%
df_ACLS['Date'] = pd.to_datetime(df_ACLS['Date'])
# 'Date' 컬럼을 기준으로 병합
df_acls = pd.merge(df_ACLS, df_acls_original, on='Date', how='inner')
df_acls
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1877316287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ACLS['Date'] = pd.to_datetime(df_ACLS['Date'])
#                                                 head       Date  \
# 0  Axcelis Technologies director sells over $137k... 2024-05-21
# 1  Tech sector: Which stocks will dominate the ma... 2024-04-26
# 2  Axcelis Tech receives Investment Bank Analyst ... 2024-05-03
# 3  Axcelis Tech receives Investment Bank Analyst ... 2024-05-03
#
#                                                 Text   type        src  \
# 0                                   pure advertising  $ACLS  investing
# 1                                   pure advertising  $ACLS  investing
# ...

# %%
df_ASX['Date'] = pd.to_datetime(df_ASX['Date'])
# 'Date' 컬럼을 기준으로 병합
df_asx = pd.merge(df_ASX, df_asx_original, on='Date', how='inner')
df_asx
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\2790623035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ASX['Date'] = pd.to_datetime(df_ASX['Date'])
#                                                 head       Date  \
# 0  US picks 31 regional hubs to spur tech innovation 2023-10-23
#
#                                                 Text  type        src  Open  \
# 0  Stop throwing public money at your pet project...  $ASX  investing   7.6
#
#    High   Low  Close  Adj Close   Volume
# 0  7.77  7.54   7.63       7.63  4768800

# %%
df_ENTG['Date'] = pd.to_datetime(df_ENTG['Date'])
# 'Date' 컬럼을 기준으로 병합
df_entg = pd.merge(df_ENTG, df_entg_original, on='Date', how='inner')
df_entg
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3341176895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ENTG['Date'] = pd.to_datetime(df_ENTG['Date'])
#                                                 head       Date  \
# 0  Entegris SVP Olivier Blachier sells $265,806 i... 2024-05-17
# 1  Entegris stock dips following Q1 revenue miss,... 2024-05-01
# 2  Entegris stock dips following Q1 revenue miss,... 2024-05-01
# 3  Entegris stock dips following Q1 revenue miss,... 2024-05-01
# 4  Entegris stock dips following Q1 revenue miss,... 2024-05-01
# 5  Entegris stock dips following Q1 revenue miss,... 2024-05-01
# 6  Entegris stock dips following Q1 revenue miss,... 2024-05-01
# ...

# %%
df_KLAC['Date'] = pd.to_datetime(df_KLAC['Date'])
# 'Date' 컬럼을 기준으로 병합
df_klac = pd.merge(df_KLAC, df_klac_original, on='Date', how='inner')
df_klac
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\4241296405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_KLAC['Date'] = pd.to_datetime(df_KLAC['Date'])
#                                               head       Date  \
# 0  This is the reason why chip stocks are up today 2024-05-10
# 1  This is the reason why chip stocks are up today 2024-05-10
#
#                                                 Text   type        src   Open  \
# 0  Its all priced in semic valuation is priced wa...  $KLAC  investing  720.0
# 1               Stop mis inform people. AMD is down.  $KLAC  investing  720.0
#
#     High         Low      Close   Adj Close  Volume
# 0  728.0  713.059998  718.27002  716.811646  448800
# ...

# %%
df_LSCC['Date'] = pd.to_datetime(df_LSCC['Date'])
# 'Date' 컬럼을 기준으로 병합
df_lscc = pd.merge(df_LSCC, df_lscc_original, on='Date', how='inner')
df_lscc
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3750703079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_LSCC['Date'] = pd.to_datetime(df_LSCC['Date'])
#                                                  head       Date  \
# 0   Lattice Semiconductor stock target raised by BofA 2024-04-30
# 1   Lattice semiconductor receives Investment Bank... 2024-05-13
# 2   Lattice semiconductor receives Investment Bank... 2024-05-13
# 3   Lattice semiconductor receives Investment Bank... 2024-05-13
# 4   Lattice semiconductor receives Investment Bank... 2024-05-13
# 5   Lattice semiconductor receives Investment Bank... 2024-05-13
# 6   Lattice semiconductor receives Investment Bank... 2024-05-13
# ...

# %%
df_MKSI['Date'] = pd.to_datetime(df_MKSI['Date'])
# 'Date' 컬럼을 기준으로 병합
df_mksi = pd.merge(df_MKSI, df_mksi_original, on='Date', how='inner')
df_mksi
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3931123060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_MKSI['Date'] = pd.to_datetime(df_MKSI['Date'])
#                                                 head       Date  \
# 0  MKS Instruments Pricing of Upsized Private Off... 2024-05-13
#
#                           Text   type        src   Open    High         Low  \
# 0  What a scam to shareholders  $MKSI  investing  124.0  124.43  118.449997
#
#         Close   Adj Close   Volume
# 0  118.709999  118.709999  2696900

# %%
df_ON['Date'] = pd.to_datetime(df_ON['Date'])
# 'Date' 컬럼을 기준으로 병합
df_on = pd.merge(df_ON, df_on_original, on='Date', how='inner')
df_on
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\2467611524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ON['Date'] = pd.to_datetime(df_ON['Date'])
#                                                  head       Date  \
# 0   On Semiconductor director sells shares worth o... 2024-05-17
# 1   On Semiconductor director sells shares worth o... 2024-05-17
# 2   On Semiconductor director sells shares worth o... 2024-05-17
# 3           March chip sales above seasonality - Citi 2024-05-06
# 4           March chip sales above seasonality - Citi 2024-05-06
# 5           March chip sales above seasonality - Citi 2024-05-06
# 6           March chip sales above seasonality - Citi 2024-05-06
# ...

# %%
df_RMBS['Date'] = pd.to_datetime(df_RMBS['Date'])
# 'Date' 컬럼을 기준으로 병합
df_rmbs = pd.merge(df_RMBS, df_rmbs_original, on='Date', how='inner')
df_rmbs
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1684214159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RMBS['Date'] = pd.to_datetime(df_RMBS['Date'])
#                                                  head       Date  \
# 0   Rambus to Present at Upcoming Investor Confere... 2024-05-14
# 1   Rambus director Eric Stang sells over $643k in... 2024-05-08
# 2   Rambus director Eric Stang sells over $643k in... 2024-05-08
# 3   Rambus director Eric Stang sells over $643k in... 2024-05-08
# 4   Rambus director Eric Stang sells over $643k in... 2024-05-08
# 5   Rambus director Eric Stang sells over $643k in... 2024-05-08
# 6   Rambus director Eric Stang sells over $643k in... 2024-05-08
# ...

# %%
df_QRVO['Date'] = pd.to_datetime(df_QRVO['Date'])
# 'Date' 컬럼을 기준으로 병합
df_qrvo = pd.merge(df_QRVO, df_qrvo_original, on='Date', how='inner')
df_qrvo
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1188301989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_QRVO['Date'] = pd.to_datetime(df_QRVO['Date'])
#                                                  head       Date  \
# 0   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# 1   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# 2   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# 3   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# 4   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# 5   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# 6   Qorvo Announces Verdict and Damage Award in Li... 2024-05-21
# ...

# %%
df_STM['Date'] = pd.to_datetime(df_STM['Date'])
# 'Date' 컬럼을 기준으로 병합
df_stm = pd.merge(df_STM, df_stm_original, on='Date', how='inner')
df_stm
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3030764596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_STM['Date'] = pd.to_datetime(df_STM['Date'])
#                                                 head       Date  \
# 0  STMicro cuts FY revenue outlook as softer car ... 2024-04-25
# 1  STMicro cuts FY revenue outlook as softer car ... 2024-04-25
# 2  STMicro cuts FY revenue outlook as softer car ... 2024-04-25
# 3  STMicro cuts FY revenue outlook as softer car ... 2024-04-25
# 4  S?¢icroelectronics Reports 2024 First Quarter ... 2024-04-25
# 5  S?¢icroelectronics Reports 2024 First Quarter ... 2024-04-25
#
#                                                 Text  type        src   Open  \
# ...

# %%
df_SWKS['Date'] = pd.to_datetime(df_SWKS['Date'])
# 'Date' 컬럼을 기준으로 병합
df_swks = pd.merge(df_SWKS, df_swks_original, on='Date', how='inner')
df_swks
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\3794600227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_SWKS['Date'] = pd.to_datetime(df_SWKS['Date'])
#                                                  head       Date  \
# 0   Skyworks downgraded amid iPhone content loss c... 2024-05-09
# 1    Skyworks shares target cut on iPhone socket loss 2024-05-01
# 2    Skyworks shares target cut on iPhone socket loss 2024-05-01
# 3    Skyworks shares target cut on iPhone socket loss 2024-05-01
# 4    Skyworks shares target cut on iPhone socket loss 2024-05-01
# 5    Skyworks shares target cut on iPhone socket loss 2024-05-01
# 6    Skyworks shares target cut on iPhone socket loss 2024-05-01
# ...

# %%
# df_TSMC['Date'] = pd.to_datetime(df_TSMC['Date'])
# # 'Date' 컬럼을 기준으로 병합
# df_tsmc = pd.merge(df_TSMC, df_tsmc_original, on='Date', how='inner')
# df_tsmc

# %%
df_UMC['Date'] = pd.to_datetime(df_UMC['Date'])
# 'Date' 컬럼을 기준으로 병합
df_umc = pd.merge(df_UMC, df_umc_original, on='Date', how='inner')
df_umc
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\1024428792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_UMC['Date'] = pd.to_datetime(df_UMC['Date'])
#                                                 head       Date  \
# 0  UMC's 'better-than-expected' Q1 results prompt... 2024-04-24
# 1  United Microelectronics reports in-line first ... 2024-04-24
# 2  Earnings call: UMC reports Q4 results, project... 2024-01-31
#
#                                                 Text  type        src  Open  \
# 0  No wonder giving the bad utilation rates at In...  $UMC  investing  7.68
# 1  Anyone suckered into buying nvda or amd are ju...  $UMC  investing  7.68
# 2                           and along came.microsoft  $UMC  investing  7.84
# ...

# %%
df_WOLF['Date'] = pd.to_datetime(df_WOLF['Date'])
# 'Date' 컬럼을 기준으로 병합
df_wolf = pd.merge(df_WOLF, df_wolf_original, on='Date', how='inner')
df_wolf
# Out:
# C:\Users\still\AppData\Local\Temp\ipykernel_15816\383828893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_WOLF['Date'] = pd.to_datetime(df_WOLF['Date'])
#                                                 head       Date  \
# 0  Wolfspeed To Participate in Upcoming Investor ... 2024-05-15
# 1  Wolfspeed stock downgraded amid EV slowdown, p... 2024-05-02
# 2      Wolfspeed stock slips as guidance disappoints 2024-05-02
# 3  Wolfspeed stock PT lowered by Citi on margin m... 2024-05-02
# 4  Cree Inc. receives Investment Bank Analyst Rat... 2024-05-02
# 5  Cree Inc. receives Investment Bank Analyst Rat... 2024-05-02
#
#                                                 Text   type        src  \
# ...

# %%
import pandas as pd

# 데이터 프레임 리스트
dfs = [df_acls,df_asx,df_entg,df_klac,df_lscc,df_mksi,df_on,df_qrvo,df_rmbs,df_stm,df_swks,df_umc,df_wolf,df_adi, df_amat, df_amd, df_asml, df_avgo, df_intc, df_lrcx, df_mchp, df_mpwr, df_mrvl, df_mu, df_nvda, df_nxpi, df_qcom, df_ter, df_txn]

# 각 데이터 프레임에서 Unnamed: 0 컬럼 제외하고 결합
combined_df_investing = pd.concat(dfs, ignore_index=True)

# 결과 데이터 프레임 출력
combined_df_investing.head()
# Out:
#                                                 head       Date  \
# 0  Axcelis Technologies director sells over $137k... 2024-05-21
# 1  Tech sector: Which stocks will dominate the ma... 2024-04-26
# 2  Axcelis Tech receives Investment Bank Analyst ... 2024-05-03
# 3  Axcelis Tech receives Investment Bank Analyst ... 2024-05-03
# 4  US picks 31 regional hubs to spur tech innovation 2023-10-23
#
#                                                 Text   type        src  \
# 0                                   pure advertising  $ACLS  investing
# 1                                   pure advertising  $ACLS  investing
# 2                                             ?¤£?  $ACLS  investing
# 3  what is to do with CZR? in Value it is to buy ...  $ACLS  investing
# 4  Stop throwing public money at your pet project...   $ASX  investing
#
#          Open        High         Low       Close   Adj Close   Volume
# 0  112.989998  113.820000  111.910004  112.190002  112.190002   337300
# ...

# %%
combined_df_investing
# Out:
#                                                   head       Date  \
# 0    Axcelis Technologies director sells over $137k... 2024-05-21
# 1    Tech sector: Which stocks will dominate the ma... 2024-04-26
# 2    Axcelis Tech receives Investment Bank Analyst ... 2024-05-03
# 3    Axcelis Tech receives Investment Bank Analyst ... 2024-05-03
# 4    US picks 31 regional hubs to spur tech innovation 2023-10-23
# ..                                                 ...        ...
# 778  Texas Instru receives Investment Bank Analyst ... 2024-05-15
# 779  Texas Instru receives Investment Bank Analyst ... 2024-05-15
# 780  Texas Instru receives Investment Bank Analyst ... 2024-05-15
# 781  Texas Instru receives Investment Bank Analyst ... 2024-05-15
# 782  Texas Instru receives Investment Bank Analyst ... 2024-05-15
#
#                                                   Text   type        src  \
# 0                                     pure advertising  $ACLS  investing
# ...

# %%
df.shape
# Out:
# (797, 5)

# %%
combined_df_investing.shape
# Out:
# (783, 11)

# %%
combined_df_investing.to_excel("combined_df_investing.xlsx", index=False)

# %%
import pandas as pd
import yfinance as yf

# 파일 경로 및 파일 이름
# A = 'm_ASML'
excel_file = f'C:\Users\still\crawler\combined_df_investing.xlsx'

# 엑셀 파일 불러오기
df = pd.read_excel(excel_file)

# 날짜 형식을 변경하는 함수
# def convert_date_format(date_str):
#     return date_str.replace('.', '-')

# 날짜 형식 변경 적용
if 'Time' in df.columns:
    df['Time'] = df['Time'].apply(convert_date_format)

    # 빈 DataFrame 생성
    additional_data = pd.DataFrame()

    # 각 행에 대해 주가 데이터를 가져와서 추가
    for index, row in df.iterrows():
        symbol = row['type'].replace('&', '')
        date = row['Time']

        stock_data = yf.download(symbol, date)

        if not stock_data.empty:
            soxl_data = yf.download('SOXL', date)
            combined_data = pd.concat([stock_data, soxl_data.add_prefix('SOXL_')], axis=1)
            additional_data = pd.concat([additional_data, combined_data])

    # 기존 DataFrame에 새로운 데이터 추가
    result_df = pd.concat([df.reset_index(drop=True), additional_data.reset_index(drop=True)], axis=1)

    # 결과를 새로운 엑셀 파일로 저장
    result_df.to_excel(f'/content/drive/MyDrive/KDT/중간 프로젝트/네이버 주식토론방/수정한거/1다시수정한거{A}.xlsx', index=False)

    print(f"새로운 엑셀 파일이 '{A}'로 저장되었습니다.")
else:
    print("Time 열이 존재하지 않습니다. 주식 데이터를 불러오지 않습니다.")

# %%
import pandas as pd
import yfinance as yf

# 파일 경로 및 파일 이름
excel_file = f'C:\Users\still\crawler\combined_df_investing.xlsx'

# 엑셀 파일 불러오기
df = pd.read_excel(excel_file)
# Out:
#   Cell In[196], line 5
#     excel_file = f'C:\Users\still\crawler\combined_df_investing.xlsx'
#                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import FinanceDataReader as fdr
import pandas as pd
# ADI 데이터 불러오기
df_soxl = fdr.DataReader('SOXL', start='2023')
# 'Date' 인덱스를 컬럼으로 변환
df_soxl.reset_index(inplace=True)

combined_df_investing['Date'] = pd.to_datetime(combined_df_investing['Date'])
# 'Date' 컬럼을 기준으로 병합
combined_df_investing = pd.merge(combined_df_investing, df_soxl, on='Date', how='inner')
combined_df_investing

# 데이터프레임의 컬럼 이름을 변경합니다.
combined_df_investing.rename(columns={
    'Open_x': 'Open',
    'High_x': 'High',
    'Low_x': 'Low',
    'Close_x': 'Close',
    'Adj Close_x': 'Adj Close',
    'Volume_x': 'Volume',
    'Open_y': 'SOXL_Open',
    'High_y': 'SOXL_High',
    'Low_y': 'SOXL_Low',
    'Close_y': 'SOXL_Close',
    'Adj Close_y': 'SOXL_Adj Close',
    'Volume_y': 'SOXL_Volume'
}, inplace=True)
# 변경된 컬럼 이름을 확인합니다.
print(combined_df_investing.columns)
# Out:
# Index(['head', 'Date', 'Text', 'type', 'src', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume', 'SOXL_Open', 'SOXL_High', 'SOXL_Low',
#        'SOXL_Close', 'SOXL_Adj Close', 'SOXL_Volume'],
#       dtype='object')

# %%
combined_df_investing

combined_df_investing.to_excel("combined_df_investing.xlsx", index=False)
